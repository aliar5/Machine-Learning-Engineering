# %% [markdown]
# <a href="https://colab.research.google.com/github/aliar5/Machine-Learning-Engineering/blob/main/HW3Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#HW3 Question 1
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from skimage import io

# Load image
image = io.imread('/content/Tesla.jpg')  # Load image
pixels = image.reshape(-1, 3)  # Reshape to 2D (pixel values)

# Apply K-means clustering
kmeans = KMeans(n_clusters=5, random_state=42)
segmented = kmeans.fit_predict(pixels)
segmented_image = segmented.reshape(image.shape[:2])

# Display original and segmented images
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(segmented_image, cmap='viridis')
plt.title('Segmented Image')
plt.axis('off')
plt.show()
